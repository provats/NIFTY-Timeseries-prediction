# %% [markdown]
# # Support Vector Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import pandas_datareader
from sklearn.metrics import r2_score
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\pandas\compat\_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.1.0' currently installed).
#   warnings.warn(msg, UserWarning)
# C:\Program Files\Anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# ## Importing the dataset

# %%
start_date = '2015-06-12'
end_date = '2020-06-12'

# %%
data = pandas_datareader.data.get_data_yahoo('^NSEI', start_date, end_date)
data.tail()
# Out:
#                     High           Low          Open         Close    Volume  \
# Date
# 2020-06-08  10328.500000  10120.250000  10326.750000  10167.450195  936500.0
# 2020-06-09  10291.150391  10021.450195  10181.150391  10046.650391  754200.0
# 2020-06-10  10148.750000  10036.849609  10072.599609  10116.150391  632400.0
# 2020-06-11  10112.049805   9885.049805  10094.099609   9902.000000  715500.0
# 2020-06-12   9996.049805   9544.349609   9544.950195   9972.900391  796300.0
#
#                Adj Close
# Date
# 2020-06-08  10167.450195
# 2020-06-09  10046.650391
# 2020-06-10  10116.150391
# 2020-06-11   9902.000000
# 2020-06-12   9972.900391

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col4 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col4 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row3_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row3_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row3_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row3_col4 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row3_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row5_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row5_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row5_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row5_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row5_col4 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_478b2a06_ae01_11ea_a8be_8056f2546718row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_478b2a06_ae01_11ea_a8be_8056f2546718" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >High</th>        <th class="col_heading level0 col1" >Low</th>        <th class="col_heading level0 col2" >Open</th>        <th class="col_heading level0 col3" >Close</th>        <th class="col_heading level0 col4" >Volume</th>        <th class="col_heading level0 col5" >Adj Close</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_478b2a06_ae01_11ea_a8be_8056f2546718level0_row0" class="row_heading level0 row0" >High</th>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col1" class="data row0 col1" >0.998099</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col2" class="data row0 col2" >0.998982</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col3" class="data row0 col3" >0.999108</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col4" class="data row0 col4" >0.187268</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row0_col5" class="data row0 col5" >0.999108</td>
#             </tr>
#             <tr>
#                         <th id="T_478b2a06_ae01_11ea_a8be_8056f2546718level0_row1" class="row_heading level0 row1" >Low</th>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col0" class="data row1 col0" >0.998099</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col2" class="data row1 col2" >0.998976</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col3" class="data row1 col3" >0.998850</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col4" class="data row1 col4" >0.154963</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row1_col5" class="data row1 col5" >0.998850</td>
#             </tr>
#             <tr>
#                         <th id="T_478b2a06_ae01_11ea_a8be_8056f2546718level0_row2" class="row_heading level0 row2" >Open</th>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col0" class="data row2 col0" >0.998982</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col1" class="data row2 col1" >0.998976</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col3" class="data row2 col3" >0.998107</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col4" class="data row2 col4" >0.172718</td>
#                         <td id="T_478b2a06_ae01_11ea_a8be_8056f2546718row2_col5" class="data row2 col5" >0.998107</td>
#             </tr>
#             <tr>
#                         <th id="T_478b2a06_ae01_11ea_a8be_8056f2546718l

# %%
plt.figure(figsize=(16,8))
data['Close'].plot()
plt.show()

# %%
n=30
X = pd.DataFrame(index=data[['Adj Close']][0:n].index.copy())
for i in range(data.shape[0]-n):
    X[f'{i}'] = np.array(data['Adj Close'][i:n+i].values)
X = X.transpose()
X.index=data.tail(X.shape[0]).index
X = pd.concat([X,data[['Adj Close']].tail(X.shape[0])],axis = 1, sort = False)
X.drop(['Adj Close'],axis=1,inplace=True)

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col1 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col2 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col3 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col4 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col5 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col6 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col7 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col8 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col9 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col10 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col11 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col12 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col13 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col14 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col19 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col22 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col25 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col26 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col27 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col28 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row0_col29 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col0 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col2 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col3 {
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col4 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col5 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col6 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col7 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col8 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col9 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col10 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col11 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col12 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col13 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col14 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col15 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col16 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col17 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col18 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col19 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col20 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col21 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col22 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col23 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col24 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col25 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col26 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col27 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col28 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_4d174db4_ae01_11ea_88c0_8056f2546718row1_col29 {
#             background-color:  #

# %%
y = data[['Adj Close']].tail(X.shape[0])
y=y.rename(columns={'Adj Close': 'Close'})

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
d = 40
X_train = X.head(X.shape[0]-d)
y_train = y.head(X.shape[0]-d)
X_test = X.tail(d) 
y_test = y.tail(d)

# %% [markdown]
# ## Training the Multiple Linear Regression model on the Training set

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'poly')
regressor.fit(X_train, y_train)
r2_score(y_test, regressor.predict(X_test))
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5702533203924243

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.values.reshape(len(y_test),1)),1))
# Out:
# [[ 9140.73  8992.8 ]
#  [ 8931.13  9266.75]
#  [ 9362.54  9261.85]
#  [ 9186.83  8981.45]
#  [ 9195.2   9187.3 ]
#  [ 9221.66  9313.9 ]
#  [ 9295.09  9154.4 ]
#  [ 9338.05  9282.3 ]
#  [ 9211.87  9380.9 ]
#  [ 9250.63  9553.35]
#  [ 9362.31  9859.9 ]
#  [ 9593.75  9293.5 ]
#  [ 9269.7   9205.6 ]
#  [ 9016.77  9270.9 ]
#  [ 9104.    9199.05]
#  [ 9008.35  9251.5 ]
#  [ 8971.86  9239.2 ]
#  [ 9107.31  9196.55]
#  [ 9005.96  9383.55]
#  [ 9212.61  9142.75]
#  [ 9068.77  9136.85]
#  [ 8881.54  8823.25]
#  [ 8741.46  8879.1 ]
#  [ 8717.97  9066.55]
#  [ 8862.5   9106.25]
#  [ 8982.92  9039.25]
#  [ 8871.39  9029.05]
#  [ 8975.46  9314.95]
#  [ 9114.51  9490.1 ]
#  [ 9237.38  9580.3 ]
#  [ 9335.43  9826.15]
#  [ 9482.33  9979.1 ]
#  [ 9749.66 10061.55]
#  [ 9753.38 10029.1 ]
#  [ 9760.9  10142.15]
#  [ 9888.83 10167.45]
#  [ 9896.1  10046.65]
#  [ 9880.45 10116.15]
#  [ 9921.58  9902.  ]
#  [ 9788.41  9972.9 ]]

# %% [markdown]
# regressor.predict([[86.95,90.95,90,88.25]])

# %% [markdown]
# ## Visualising the Training set results

# %%
y_plt = y_train[:]
y_plt['predicted'] = np.array(regressor.predict(X_train))
plt.figure(figsize=(16,8))
y_train['Close'].plot()
y_plt['predicted'].plot()
plt.legend()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Visualising the Test set results

# %%
y_plt2 = y_test[:]
y_plt2['predicted'] = np.array(regressor.predict(X_test))
plt.figure(figsize=(16,8))
y_test['Close'].plot()
y_plt2['predicted'].plot()
plt.legend()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Visualising the Future set results

# %%
y_future = y_test[:].rename(columns={'Close': 'Future'})
for i in range(n+1,d):
    y_future['Future'][i] = regressor.predict([y_future.iloc[i-n-1:i-1,0]])

# %%
plt.figure(figsize=(16,8))
y_test['Close'].plot()
y_future['Future'].plot()
plt.legend()

# %%
r2_score(y_test.tail(d-n).values, y_future.tail(d-n).values)
# Out:
# -62.99182836878306
